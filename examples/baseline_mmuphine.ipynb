# %%
import pandas as pd
X_filtered_df3 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/X_df3_filtered_cutoff0.005.csv", index_col=0)
meta_filtered_df3 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/meta_df3_filtered_cutoff0.005.csv", index_col=0)
batch_filtered_df3 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/batch_df3_filtered_cutoff0.005.csv", index_col=0)

X_filtered_df4 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/X_df4_filtered_cutoff0.005.csv", index_col=0)
meta_filtered_df4 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/meta_df4_filtered_cutoff0.005.csv", index_col=0)
batch_filtered_df4 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/batch_df4_filtered_cutoff0.005.csv", index_col=0)

X_filtered_df5 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/X_df5_filtered_cutoff0.05.csv", index_col=0)
meta_filtered_df5 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/meta_df5_filtered_cutoff0.05.csv", index_col=0)
batch_filtered_df5 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/batch_df5_filtered_cutoff0.05.csv", index_col=0)

X_filtered_df6 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/X_df6_filtered_cutoff0.1.csv", index_col=0)
meta_filtered_df6 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/meta_df6_filtered_cutoff0.1.csv", index_col=0)
batch_filtered_df6 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/batch_df6_filtered_cutoff0.1.csv", index_col=0)

X_df3_mmuphine =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/X_df3_corrected_MMUPHin.csv", index_col=0)
X_df4_mmuphine =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/X_df4_corrected_MMUPHin.csv", index_col=0)
X_df5_mmuphine =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/X_df5_corrected_MMUPHin.csv", index_col=0)
X_df6_mmuphine =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/X_df6_corrected_MMUPHin.csv", index_col=0)

# %%
X_filtered_df5 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/X_df5_filtered_cutoff0.05.csv", index_col=0)
meta_filtered_df5 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/meta_df5_filtered_cutoff0.05.csv", index_col=0)
batch_filtered_df5 =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/batch_df5_filtered_cutoff0.05.csv", index_col=0)

X_df5_mmuphine =pd.read_csv("/DATA/WGS_study/YSL/projects/latentgee/examples/data/X_df5_corrected_MMUPHin.csv", index_col=0)

# %%
from functions import evaluate_batch_correction
mmuphin_df3_result = evaluate_batch_correction(
    X_before     = X_filtered_df3.values,
    X_after      = X_df3_mmuphine.values,
    batch_labels = batch_filtered_df3['Study'].values,
    bio_labels   = meta_filtered_df3['hivstatus'].values,
    renormalize  = True,
    label        = "df3 — MMUPHin"
)
# Out:
# =======================================================
#   df3 — MMUPHin
# =======================================================
#                         Before   After  Change
# Metric
# PERMANOVA R² (batch) ↓  0.1835  0.0403 -0.1432
# PERMANOVA R² (bio) ↑    0.0041  0.0048  0.0006
# kBET acceptance rate ↑  0.2051  0.5876  0.3825
# ASW (batch) → 0        -0.1002 -0.0916  0.0086
# ASW (bio) ↑            -0.0245 -0.0221  0.0024
# =======================================================

# %%
from functions import evaluate_batch_correction
mmuphin_df4_result = evaluate_batch_correction(
    X_before     = X_filtered_df4.values,
    X_after      = X_df4_mmuphine.values,
    batch_labels = batch_filtered_df4['Study'].values,
    bio_labels   = meta_filtered_df4['hivstatus'].values,
    renormalize  = True,
    label        = "df4 — MMUPHin"
)
# Out:
# =======================================================
#   df4 — MMUPHin
# =======================================================
#                         Before   After  Change
# Metric
# PERMANOVA R² (batch) ↓  0.2649  0.0405 -0.2244
# PERMANOVA R² (bio) ↑    0.0039  0.0047  0.0008
# kBET acceptance rate ↑  0.0085  0.5780  0.5694
# ASW (batch) → 0        -0.1329 -0.0906  0.0423
# ASW (bio) ↑            -0.0261 -0.0217  0.0043
# =======================================================

# %%
X_df5_mmuphine
# Out:
#           Abiotrophia  Acetanaerobacterium  Acetitomaculum  Acetivibrio  \
# 4EP1                0                  362               0            0
# 4EP10               0                    0               0            0
# 4EP12               0                   48               0            0
# 4EP15               0                   45               0            0
# 4EP17               0                    8              11            0
# ...               ...                  ...             ...          ...
# rgn.9.13            0                    0               0            0
# rgn.9.2             0                    0               0            0
# rgn.9.3             0                    1               0            0
# rgn.9.6             0                    5               0            0
# rgn.9.9             0                    0               0            0
#
#           Acetoanaerobium  Acetobacter  Achromobacter  Acidaminobacter  \
# 4EP1                    0            0              0                0
# 4EP10                   0            0              0                0
# 4EP12                   0            0              0                0
# 4EP15                   0            0              0                0
# 4EP17                   0            0              0                0
# ...                   ...          ...            ...              ...
# rgn.9.13                0            0              0                0
# rgn.9.2                 0            0              0                0
# rgn.9.3                 0            0              0                0
# rgn.9.6                 0            0              0                0
# rgn.9.9                 0            0              0                0
#
#           Acidaminococcus  Acidovorax  ...  Varibaculum  Variovorax  \
# 4EP1                  531           0  ...            0           0
# 4EP10                 569           0  ...            0           0
# 4EP12                  91           0  ...            0           0
# 4EP15                  10           0  ...            0           0
# 4EP17                   6           0  ...            0           0
# ...                   ...         ...  ...          ...         ...
# rgn.9.13                0           0  ...            0           1
# rgn.9.2                 0           0  ...            5           0
# rgn.9.3                 0           0  ...            0           0
# rgn.9.6                 0           0  ...            0           0
# rgn.9.9                 0           0  ...           77           0
#
#           Veillonella  Vibrio  Victivallis  Virgibacillus  Vulcanibacillus  \
# 4EP1                0       0          169              0                0
# 4EP10              75       0            0              0                0
# 4EP12               0       0           18              0                0
# 4EP15               0       0           77              0                0
# 4EP17               0       0            0              0                0
# ...               ...     ...          ...            ...              ...
# rgn.9.13            2       0            0              0                0
# rgn.9.2             1       0            0              0                0
# rgn.9.3            25       0            0              0                0
# rgn.9.6             0       0            0              0                0
# rgn.9.9             3       0            0              0                0
#
#           Weissella  Yersinia  Zimmermannella
# 4EP1              0         0               0
# 4EP10             0         0               0
# 4EP12             5         0               0
# 4EP15             0         0               0
# 4EP17             0         0               0
# ...             ...       ...             ...
# rgn.9.13         14         0               0
# rgn.9.2           0         0               0
# rgn.9.3           3         0               0
# rgn.9.6           0         0               0
# rgn.9.9           0         0               0
#
# [936 rows x 353 columns]

# %%
from functions import evaluate_batch_correction
mmuphin_df5_result = evaluate_batch_correction(
    X_before     = X_filtered_df5.values,
    X_after      = X_df5_mmuphine.values,
    batch_labels = batch_filtered_df5['Study'].values,
    bio_labels   = meta_filtered_df5['hivstatus'].values,
    renormalize  = True,
    label        = "df5 — MMUPHin"
)
# Out:
# =======================================================
#   df5 — MMUPHin
# =======================================================
#                         Before   After  Change
# Metric
# PERMANOVA R² (batch) ↓  0.2269  0.0313 -0.1957
# PERMANOVA R² (bio) ↑    0.0041  0.0047  0.0006
# kBET acceptance rate ↑  0.0535  0.4897  0.4362
# ASW (batch) → 0         0.1003 -0.0255 -0.1259
# ASW (bio) ↑            -0.0079 -0.0080 -0.0001
# =======================================================

# %%
from functions import evaluate_batch_correction
mmuphin_df6result = evaluate_batch_correction(
    X_before     = X_filtered_df6.values,
    X_after      = X_df6_mmuphine.values,
    batch_labels = batch_filtered_df6['Study'].values,
    bio_labels   = meta_filtered_df6['hivstatus'].values,
    renormalize  = True,
    label        = "df6 — MMUPHin"
)
# Out:
# =======================================================
#   df6 — MMUPHin
# =======================================================
#                         Before   After  Change
# Metric
# PERMANOVA R² (batch) ↓  0.2234  0.0318 -0.1916
# PERMANOVA R² (bio) ↑    0.0073  0.0047 -0.0026
# kBET acceptance rate ↑  0.0494  0.4938  0.4444
# ASW (batch) → 0         0.1299 -0.0274 -0.1572
# ASW (bio) ↑            -0.0145 -0.0081  0.0065
# =======================================================
